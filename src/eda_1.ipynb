# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# The Following is a basic exploration of the Harvard Dataverse data set.

# %%
dataverse_path = Path() / 'data' / 'Garlick_StateLegislationPolicy.0.1.dta'
dataverse = pd.read_stata(dataverse_path)
dataverse.head(10)
# Out:
#   state           polname glcode  \
# 0    AK       Agriculture  G0400
# 1    AK        Tax Policy  G0208
# 2    AK                    G0800
# 3    AK                    G0700
# 4    AK              Bank  G1500
# 5    AK                    G0800
# 6    AK        Tax Policy  G0208
# 7    AK         Education  G0600
# 8    AK  Local Government  G2400
# 9    AK      Construction  G1400
#
#                                             lex_sess lex_pre lex_no  year1  \
# 0  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.    110   1991
# 1  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.     12   1991
# 2  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.     12   1991
# 3  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.    140   1991
# 4  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.    160   1991
# 5  17TH LEGISLATURE -- SECOND REGULAR SESSION (1992)    H.B.    196   1991
# ...

# %%
len(dataverse)
# Out:
# 984966

# %% [markdown]
# There are 984,966 bills in this dataset.

# %%
dataverse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984966 entries, 0 to 984965
# Data columns (total 11 columns):
# state          984966 non-null object
# polname        984966 non-null object
# glcode         984966 non-null object
# lex_sess       984966 non-null object
# lex_pre        984966 non-null object
# lex_no         984966 non-null object
# year1          984966 non-null int16
# year2          984966 non-null int16
# lex_bill       984966 non-null object
# ndate_intro    984966 non-null datetime64[ns]
# ndate_last     984965 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int16(2), object(7)
# memory usage: 78.9+ MB

# %% [markdown]
# Information on Features of this Dataset:
#     - "state" : 2 letter identifier for State of given bill
#     - "polname" : Name of policy areas within scope of harvard's dataset. If not within the original 22 policy areas, this feature is left empty
#     - "glcode" :
